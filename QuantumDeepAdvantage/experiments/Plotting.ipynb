# %%
import os
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
# Plot Experiment1

data = []
for filename in os.listdir('experiment1/cumu_rewards/'):
    with open('experiment1/cumu_rewards/' + filename, 'r') as f:
        data.append(f.readlines())
        
for i in range(len(data)):
    data[i] = [d.rstrip() for d in data[i]]
    data[i] = [float(d) for d in data[i]]

fig, ax = plt.subplots()
for i in range(len(data)):
    ax.plot([j for j in range(len(data[i]))], data[i])

plt.xlabel('Episodes')
plt.ylabel('Cumulative Reward')
plt.title('γ = 0.9, α = 0.01')

plt.savefig('experiment1plots.png', bbox_inches='tight')

# %%
# Plot Experiment 2

# %%
data1 = []
for filename in os.listdir('experiment2/cumu_rewards/g0.9a0.01/'):
    with open('experiment2/cumu_rewards/g0.9a0.01/' + filename, 'r') as f:
        data1.append(f.readlines())
        
for i in range(len(data1)):
    data1[i] = [d.rstrip() for d in data1[i]]
    data1[i] = [float(d) for d in data1[i]]        
        
data2 = []
for filename in os.listdir('experiment2/cumu_rewards/g0.9a0.001/'):
    with open('experiment2/cumu_rewards/g0.9a0.001/' + filename, 'r') as f:
        data2.append(f.readlines())

for i in range(len(data2)):
    data2[i] = [d.rstrip() for d in data2[i]]
    data2[i] = [float(d) for d in data2[i]] 
    
data3 = []
for filename in os.listdir('experiment2/cumu_rewards/g0.99a0.01/'):
    with open('experiment2/cumu_rewards/g0.99a0.01/' + filename, 'r') as f:
        data3.append(f.readlines())
        
        
for i in range(len(data3)):
    data3[i] = [d.rstrip() for d in data3[i]]
    data3[i] = [float(d) for d in data3[i]] 
    
data4 = []
for filename in os.listdir('experiment2/cumu_rewards/g0.99a0.001/'):
    with open('experiment2/cumu_rewards/g0.99a0.001/' + filename, 'r') as f:
        data4.append(f.readlines())
        
for i in range(len(data4)):
    data4[i] = [d.rstrip() for d in data4[i]]
    data4[i] = [float(d) for d in data4[i]]

# %%
fig, axs = plt.subplots(2,2)

fig.set_figheight(12)
fig.set_figwidth(12)

axs[0,0].set_title('γ = 0.9, α = 0.01')
for i in range(len(data1)):
    axs[0,0].plot([j for j in range(len(data1[i]))], data1[i])
    axs[0,0].set_xlabel('Episodes')
    axs[0,0].set_ylabel('Cumulative Reward')

axs[0,1].set_title('γ = 0.9, α = 0.001')
for i in range(len(data2)):
    axs[0,1].plot([j for j in range(len(data2[i]))], data2[i])
    axs[0,1].set_xlabel('Episodes')
    axs[0,1].set_ylabel('Cumulative Reward')

axs[1,0].set_title('γ = 0.99, α = 0.01')
for i in range(len(data3)):
    axs[1,0].plot([j for j in range(len(data3[i]))], data3[i])
    axs[1,0].set_xlabel('Episodes')
    axs[1,0].set_ylabel('Cumulative Reward')

axs[1,1].set_title('γ = 0.99, α = 0.001')
for i in range(len(data4)):
    axs[1,1].plot([j for j in range(len(data4[i]))], data4[i])
    axs[1,1].set_xlabel('Episodes')
    axs[1,1].set_ylabel('Cumulative Reward')


plt.xlabel('Episodes')
plt.ylabel('Cumulative Reward')

plt.savefig('experiment2plots.png', bbox_inches='tight')

# %%
# Plot Experiment 3 alpha 0.01

data1 = []
for filename in os.listdir('experiment3/g0.9a0.01/'):
    with open('experiment3/g0.9a0.01/' + filename, 'r') as f:
        data1.append(f.readlines())
        
for i in range(len(data1)):
    data1[i] = [d.rstrip() for d in data1[i]]
    data1[i] = [float(d) for d in data1[i]]        
        
data2 = []
for filename in os.listdir('experiment3/g0.7a0.01/'):
    with open('experiment3/g0.7a0.01/' + filename, 'r') as f:
        data2.append(f.readlines())

for i in range(len(data2)):
    data2[i] = [d.rstrip() for d in data2[i]]
    data2[i] = [float(d) for d in data2[i]] 
    
data3 = []
for filename in os.listdir('experiment3/g0.5a0.01/'):
    with open('experiment3/g0.5a0.01/' + filename, 'r') as f:
        data3.append(f.readlines())
        
        
for i in range(len(data3)):
    data3[i] = [d.rstrip() for d in data3[i]]
    data3[i] = [float(d) for d in data3[i]] 
    
data4 = []
for filename in os.listdir('experiment3/g0.3a0.01/'):
    with open('experiment3/g0.3a0.01/' + filename, 'r') as f:
        data4.append(f.readlines())


for i in range(len(data4)):
    data4[i] = [d.rstrip() for d in data4[i]]
    data4[i] = [float(d) for d in data4[i]] 

data5 = []
for filename in os.listdir('experiment3/g0.1a0.01/'):
    with open('experiment3/g0.1a0.01/' + filename, 'r') as f:
        data5.append(f.readlines())
        
for i in range(len(data5)):
    data5[i] = [d.rstrip() for d in data5[i]]
    data5[i] = [float(d) for d in data5[i]] 
    
data1avg = [(data1[0][i]+data1[1][i]+data1[2][i])/3 for i in range(len(data1[0]))]
data2avg = [(data2[0][i]+data2[1][i]+data2[2][i])/3 for i in range(len(data2[0]))]
data3avg = [(data3[0][i]+data3[1][i]+data3[2][i])/3 for i in range(len(data3[0]))]
data4avg = [(data4[0][i]+data4[1][i]+data4[2][i])/3 for i in range(len(data4[0]))]
data5avg = [(data5[0][i]+data5[1][i]+data5[2][i])/3 for i in range(len(data5[0]))]

# %%
fig, ax = plt.subplots(figsize=(10,10))

plt.plot([j for j in range(len(data1avg))], data1avg, 'o-')

plt.plot([j for j in range(len(data2avg))], data2avg, 'o-')

plt.plot([j for j in range(len(data3avg))], data3avg, 'o-')

plt.plot([j for j in range(len(data4avg))], data4avg, 'o-')

plt.plot([j for j in range(len(data5avg))], data5avg, 'o-')

plt.xlabel('x50 Episodes')
plt.ylabel('Frequency of Correct Solution')
plt.legend(['γ = 0.9', 'γ = 0.7', 'γ = 0.5', 'γ = 0.3', 'γ = 0.1'])

plt.title('Learning Rate 10e-2')

plt.savefig('experiment3plots_a0.01.png', bbox_inches='tight')

# %%
# Plot Experiment 3 alpha 0.001

data1 = []
for filename in os.listdir('experiment3/g0.9a0.001/'):
    with open('experiment3/g0.9a0.001/' + filename, 'r') as f:
        data1.append(f.readlines())
        
for i in range(len(data1)):
    data1[i] = [d.rstrip() for d in data1[i]]
    data1[i] = [float(d) for d in data1[i]]        
        
data2 = []
for filename in os.listdir('experiment3/g0.7a0.001/'):
    with open('experiment3/g0.7a0.001/' + filename, 'r') as f:
        data2.append(f.readlines())

for i in range(len(data2)):
    data2[i] = [d.rstrip() for d in data2[i]]
    data2[i] = [float(d) for d in data2[i]] 
    
data3 = []
for filename in os.listdir('experiment3/g0.5a0.001/'):
    with open('experiment3/g0.5a0.001/' + filename, 'r') as f:
        data3.append(f.readlines())
        
        
for i in range(len(data3)):
    data3[i] = [d.rstrip() for d in data3[i]]
    data3[i] = [float(d) for d in data3[i]] 
    
data4 = []
for filename in os.listdir('experiment3/g0.3a0.001/'):
    with open('experiment3/g0.3a0.001/' + filename, 'r') as f:
        data4.append(f.readlines())


for i in range(len(data4)):
    data4[i] = [d.rstrip() for d in data4[i]]
    data4[i] = [float(d) for d in data4[i]] 

data5 = []
for filename in os.listdir('experiment3/g0.1a0.001/'):
    with open('experiment3/g0.1a0.001/' + filename, 'r') as f:
        data5.append(f.readlines())
        
for i in range(len(data5)):
    data5[i] = [d.rstrip() for d in data5[i]]
    data5[i] = [float(d) for d in data5[i]] 
    
data1avg = [(data1[0][i]+data1[1][i]+data1[2][i])/3 for i in range(len(data1[0]))]
data2avg = [(data2[0][i]+data2[1][i]+data2[2][i])/3 for i in range(len(data2[0]))]
data3avg = [(data3[0][i]+data3[1][i]+data3[2][i])/3 for i in range(len(data3[0]))]
data4avg = [(data4[0][i]+data4[1][i]+data4[2][i])/3 for i in range(len(data4[0]))]
data5avg = [(data5[0][i]+data5[1][i]+data5[2][i])/3 for i in range(len(data5[0]))]

# %%
fig, ax = plt.subplots(figsize=(10,10))

plt.plot([j for j in range(len(data1avg))], data1avg, 'o-')

plt.plot([j for j in range(len(data2avg))], data2avg, 'o-')

plt.plot([j for j in range(len(data3avg))], data3avg, 'o-')

plt.plot([j for j in range(len(data4avg))], data4avg, 'o-')

plt.plot([j for j in range(len(data5avg))], data5avg, 'o-')

plt.xlabel('x50 Episodes')
plt.ylabel('Frequency of Correct Solution')
plt.legend(['γ = 0.9', 'γ = 0.7', 'γ = 0.5', 'γ = 0.3', 'γ = 0.1'])

plt.title('Learning Rate 10e-3')

plt.savefig('experiment3plots_a0.001.png', bbox_inches='tight')

# %%
# Plot Experiment 3 alpha 0.0001

data1 = []
for filename in os.listdir('experiment3/g0.9a0.0001/'):
    with open('experiment3/g0.9a0.0001/' + filename, 'r') as f:
        data1.append(f.readlines())
        
for i in range(len(data1)):
    data1[i] = [d.rstrip() for d in data1[i]]
    data1[i] = [float(d) for d in data1[i]]        
        
data2 = []
for filename in os.listdir('experiment3/g0.7a0.0001/'):
    with open('experiment3/g0.7a0.0001/' + filename, 'r') as f:
        data2.append(f.readlines())

for i in range(len(data2)):
    data2[i] = [d.rstrip() for d in data2[i]]
    data2[i] = [float(d) for d in data2[i]] 
    
data3 = []
for filename in os.listdir('experiment3/g0.5a0.0001/'):
    with open('experiment3/g0.5a0.0001/' + filename, 'r') as f:
        data3.append(f.readlines())
        
        
for i in range(len(data3)):
    data3[i] = [d.rstrip() for d in data3[i]]
    data3[i] = [float(d) for d in data3[i]] 
    
data4 = []
for filename in os.listdir('experiment3/g0.3a0.0001/'):
    with open('experiment3/g0.3a0.0001/' + filename, 'r') as f:
        data4.append(f.readlines())


for i in range(len(data4)):
    data4[i] = [d.rstrip() for d in data4[i]]
    data4[i] = [float(d) for d in data4[i]] 

data5 = []
for filename in os.listdir('experiment3/g0.1a0.0001/'):
    with open('experiment3/g0.1a0.0001/' + filename, 'r') as f:
        data5.append(f.readlines())
        
for i in range(len(data5)):
    data5[i] = [d.rstrip() for d in data5[i]]
    data5[i] = [float(d) for d in data5[i]] 
    
data1avg = [(data1[0][i]+data1[1][i]+data1[2][i])/3 for i in range(len(data1[0]))]
data2avg = [(data2[0][i]+data2[1][i]+data2[2][i])/3 for i in range(len(data2[0]))]
data3avg = [(data3[0][i]+data3[1][i]+data3[2][i])/3 for i in range(len(data3[0]))]
data4avg = [(data4[0][i]+data4[1][i]+data4[2][i])/3 for i in range(len(data4[0]))]
data5avg = [(data5[0][i]+data5[1][i]+data5[2][i])/3 for i in range(len(data5[0]))]

# %%
fig, ax = plt.subplots(figsize=(10,10))

plt.plot([j for j in range(len(data1avg))], data1avg, 'o-')

plt.plot([j for j in range(len(data2avg))], data2avg, 'o-')

plt.plot([j for j in range(len(data3avg))], data3avg, 'o-')

plt.plot([j for j in range(len(data4avg))], data4avg, 'o-')

plt.plot([j for j in range(len(data5avg))], data5avg, 'o-')

plt.xlabel('x50 Episodes')
plt.ylabel('Frequency of Correct Solution')
plt.legend(['γ = 0.9', 'γ = 0.7', 'γ = 0.5', 'γ = 0.3', 'γ = 0.1'])
plt.title('Learning Rate 10e-4')

plt.savefig('experiment3plots_a0.0001.png', bbox_inches='tight')
